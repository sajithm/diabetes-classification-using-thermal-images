# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import Activation, BatchNormalization, Dropout, Flatten, Rescaling
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers, callbacks
import time, json, os, shutil, argparse
import warnings
warnings.simplefilter("ignore")

# %%
epochs = 100
batch_size = 160
labels = ["0", "1"]
dir_models = "./Models/HC/OG"
dir_training = "./Data/HC/OG/"
dir_validation = "./Data/HC/O/Validation"
img_width, img_height, img_depth = 320, 240, 3
path_model = os.path.join(dir_models, 'cnn.h5')
path_history = os.path.join(dir_models, 'cnn.csv')

# %%
model = Sequential()

k_reg = tf.keras.regularizers.l2(0.0001)
k_init = tf.keras.initializers.RandomNormal(stddev=0.02)

model.add(Rescaling(1./127.5, offset=-1, input_shape=(img_width, img_height, img_depth)))
model.add(MaxPooling2D(pool_size=(4,4)))

model.add(Conv2D(128, (3, 3), kernel_initializer=k_init, kernel_regularizer=k_reg))
model.add(MaxPooling2D())
model.add(Activation('relu'))

model.add(Conv2D(256, (3, 3), kernel_initializer=k_init, kernel_regularizer=k_reg))
model.add(MaxPooling2D())
model.add(Activation('relu'))

model.add(Flatten())
model.add(Dropout(0.5))

model.add(Dense(512, kernel_regularizer=k_reg))
model.add(Activation('relu'))

model.add(Dense(1))
model.add(Activation('sigmoid'))

#model.summary()

model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Nadam(),
              metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator()
test_datagen = ImageDataGenerator()

train_generator = train_datagen.flow_from_directory(
    dir_training,
    target_size=(img_width, img_height),
    color_mode="rgb",
    batch_size=batch_size,
    class_mode='binary',
    shuffle=True,
    seed=42)

validation_generator = test_datagen.flow_from_directory(
    dir_validation,
    target_size=(img_width, img_height),
    color_mode="rgb",
    batch_size=batch_size,
    class_mode='binary',
    shuffle=True,
    seed=42)
# Out:
# Found 320 images belonging to 2 classes.
# Found 20 images belonging to 2 classes.

# %%
callback_log = callbacks.CSVLogger(path_history, append=True)
callback_model_save = callbacks.ModelCheckpoint(filepath=path_model, save_weights_only=False, monitor='val_accuracy', mode='max', save_best_only=True)

# %%
time_in = time.time()

hist = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator,
    callbacks=[callback_log, callback_model_save])

time_out = time.time()
print('\n', 'Time cost:', '\n', time_out-time_in)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 11s 5s/step - loss: 1.8510 - accuracy: 0.5000 - val_loss: 3.2483 - val_accuracy: 0.5000
# Epoch 2/100
# 2/2 [==============================] - 8s 4s/step - loss: 1.8456 - accuracy: 0.5000 - val_loss: 0.8291 - val_accuracy: 0.5000
# Epoch 3/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.7857 - accuracy: 0.5000 - val_loss: 0.8158 - val_accuracy: 0.5000
# Epoch 4/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.7692 - accuracy: 0.6438 - val_loss: 0.8633 - val_accuracy: 0.5000
# Epoch 5/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.7401 - accuracy: 0.5562 - val_loss: 0.8166 - val_accuracy: 0.4000
# Epoch 6/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.7003 - accuracy: 0.7469 - val_loss: 0.8451 - val_accuracy: 0.4000
# Epoch 7/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.6474 - accuracy: 0.8406 - val_loss: 1.6365 - val_accuracy: 0.4500
# Epoch 8/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.7748 - accuracy: 0.5969 - val_loss: 0.7550 - val_accuracy: 0.5000
# Epoch 9/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.6402 - accuracy: 0.8344 - val_loss: 0.9070 - val_accuracy: 0.5500
# Epoch 10/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.5282 - accuracy: 0.8438 - val_loss: 0.9213 - val_accuracy: 0.6000
# Epoch 11/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.4615 - accuracy: 0.8656 - val_loss: 0.9968 - val_accuracy: 0.4000
# Epoch 12/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.6474 - accuracy: 0.6938 - val_loss: 0.7221 - val_accuracy: 0.6500
# Epoch 13/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.4979 - accuracy: 0.8938 - val_loss: 1.0798 - val_accuracy: 0.6000
# Epoch 14/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.3829 - accuracy: 0.8781 - val_loss: 1.2523 - val_accuracy: 0.6000
# Epoch 15/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.3285 - accuracy: 0.9187 - val_loss: 1.3285 - val_accuracy: 0.5500
# Epoch 16/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.3503 - accuracy: 0.9031 - val_loss: 2.6319 - val_accuracy: 0.5000
# Epoch 17/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.6001 - accuracy: 0.7281 - val_loss: 0.9644 - val_accuracy: 0.5500
# Epoch 18/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.3446 - accuracy: 0.9281 - val_loss: 1.2798 - val_accuracy: 0.4500
# Epoch 19/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.2790 - accuracy: 0.9375 - val_loss: 1.3354 - val_accuracy: 0.5500
# Epoch 20/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.2425 - accuracy: 0.9531 - val_loss: 1.4078 - val_accuracy: 0.6000
# Epoch 21/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.2215 - accuracy: 0.9500 - val_loss: 1.5122 - val_accuracy: 0.6000
# Epoch 22/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.1974 - accuracy: 0.9656 - val_loss: 1.5776 - val_accuracy: 0.5500
# Epoch 23/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.2172 - accuracy: 0.9531 - val_loss: 2.1878 - val_accuracy: 0.6000
# Epoch 24/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.2582 - accuracy: 0.9187 - val_loss: 1.9426 - val_accuracy: 0.5500
# Epoch 25/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.1800 - accuracy: 0.9656 - val_loss: 1.5410 - val_accuracy: 0.6000
# Epoch 26/100
# 2/2 [==============================] - 10s 5s/step - loss: 0.1442 - accuracy: 0.9812 - val_loss: 1.7235 - val_accuracy: 0.6000
# Epoch 27/100
# 2/2 [==============================] - 10s 5s/step - loss: 0.1416 - accuracy: 0.9812 - val_loss: 1.6200 - val_accuracy: 0.6000
# Epoch 28/100
# 2/2 [==============================] - 10s 5s/step - loss: 0.1256 - accuracy: 0.9875 - val_loss: 1.5947 - val_accuracy: 0.6000
# Epoch 29/100
# 2/2 [==============================] - 11s 6s/step - loss: 0.1211 - accuracy: 0.9844 - val_loss: 2.0410 - val_accuracy: 0.5500
# Epoch 30/100
# 2/2 [==============================] - 11s 5s/step - loss: 0.1252 - accuracy: 0.9844 - val_loss: 2.2158 - val_accuracy: 0.6000
# Epoch 31/100
# 2/2 [==============================] - 11s 5s/step - loss: 0.1141 - accuracy: 0.9875 - val_loss: 1.9020 - val_accuracy: 0.6000
# Epoch 32/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.1070 - accuracy: 0.9937 - val_loss: 1.6197 - val_accuracy: 0.6500
# Epoch 33/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.1079 - accuracy: 0.9844 - val_loss: 1.6262 - val_accuracy: 0.6500
# Epoch 34/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.0975 - accuracy: 0.9937 - val_loss: 1.7519 - val_accuracy: 0.6000
# Epoch 35/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0831 - accuracy: 1.0000 - val_loss: 1.8442 - val_accuracy: 0.6000
# Epoch 36/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0892 - accuracy: 0.9969 - val_loss: 1.8416 - val_accuracy: 0.6500
# Epoch 37/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0815 - accuracy: 0.9969 - val_loss: 1.9117 - val_accuracy: 0.6000
# Epoch 38/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0799 - accuracy: 1.0000 - val_loss: 2.1419 - val_accuracy: 0.6000
# Epoch 39/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0775 - accuracy: 1.0000 - val_loss: 1.9130 - val_accuracy: 0.6500
# Epoch 40/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.0775 - accuracy: 1.0000 - val_loss: 1.9980 - val_accuracy: 0.6000
# Epoch 41/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.0755 - accuracy: 1.0000 - val_loss: 1.9525 - val_accuracy: 0.6500
# Epoch 42/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0748 - accuracy: 1.0000 - val_loss: 2.0355 - val_accuracy: 0.6000
# Epoch 43/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0733 - accuracy: 1.0000 - val_loss: 1.9370 - val_accuracy: 0.6500
# Epoch 44/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0688 - accuracy: 1.0000 - val_loss: 1.9649 - val_accuracy: 0.6500
# Epoch 45/100
# 2/2 [==============================] - 10s 4s/step - loss: 0.0704 - accuracy: 1.0000 - val_loss: 2.1188 - val_accuracy: 0.6000
# Epoch 46/100
# 2/2 [==============================] - 10s 5s/step - loss: 0.0670 - accuracy: 1.0000 - val_loss: 2.1678 - val_accuracy: 0.6500
# Epoch 47/100
# 2/2 [==============================] - 10s 5s/step - loss: 0.0679 - accuracy: 1.0000 - val_loss: 2.2183 - val_accuracy: 0.6000
# Epoch 48/100
# 2/2 [==============================] - 11s 6s/step - loss: 0.0693 - accuracy: 0.9969 - val_loss: 2.0818 - val_accuracy: 0.6500
# Epoch 49/100
# 2/2 [==============================] - 11s 5s/step - loss: 0.0662 - accuracy: 1.0000 - val_loss: 2.3028 - val_accuracy: 0.6000
# Epoch 50/100
# 2/2 [==============================] - 10s 5s/step - loss: 0.0656 - accuracy: 1.0000 - val_loss: 2.2550 - val_accuracy: 0.6000
# Epoch 51/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.0636 - accuracy: 1.0000 - val_loss: 2.2950 - val_accuracy: 0.6000
# Epoch 52/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.0626 - accuracy: 1.0000 - val_loss: 2.2559 - val_accuracy: 0.6500
# Epoch 53/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.0634 - accuracy: 1.0000 - val_loss: 2.3723 - val_accuracy: 0.6500
# Epoch 54/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.0614 - accuracy: 1.0000 - val_loss: 2.3258 - val_accuracy: 0.6500
# Epoch 55/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0611 - accuracy: 1.0000 - val_loss: 2.5070 - val_accuracy: 0.6500
# Epoch 56/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0634 - accuracy: 1.0000 - val_loss: 2.3847 - val_accuracy: 0.6500
# Epoch 57/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0616 - accuracy: 1.0000 - val_loss: 2.4299 - val_accuracy: 0.6500
# Epoch 58/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0593 - accuracy: 1.0000 - val_loss: 2.6143 - val_accuracy: 0.6500
# Epoch 59/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0598 - accuracy: 1.0000 - val_loss: 2.6837 - val_accuracy: 0.6000
# Epoch 60/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0589 - accuracy: 1.0000 - val_loss: 2.5762 - val_accuracy: 0.6500
# Epoch 61/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0582 - accuracy: 1.0000 - val_loss: 2.5474 - val_accuracy: 0.6500
# Epoch 62/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0569 - accuracy: 1.0000 - val_loss: 2.5806 - val_accuracy: 0.6500
# Epoch 63/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0576 - accuracy: 1.0000 - val_loss: 2.1746 - val_accuracy: 0.6500
# Epoch 64/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0571 - accuracy: 1.0000 - val_loss: 2.3312 - val_accuracy: 0.6500
# Epoch 65/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0552 - accuracy: 1.0000 - val_loss: 2.4028 - val_accuracy: 0.6500
# Epoch 66/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.0549 - accuracy: 1.0000 - val_loss: 2.3730 - val_accuracy: 0.6500
# Epoch 67/100
# 2/2 [==============================] - 10s 5s/step - loss: 0.0581 - accuracy: 1.0000 - val_loss: 2.7581 - val_accuracy: 0.6000
# Epoch 68/100
# 2/2 [==============================] - 10s 5s/step - loss: 0.0559 - accuracy: 1.0000 - val_loss: 2.3291 - val_accuracy: 0.6500
# Epoch 69/100
# 2/2 [==============================] - 11s 5s/step - loss: 0.0551 - accuracy: 1.0000 - val_loss: 2.7656 - val_accuracy: 0.6000
# Epoch 70/100
# 2/2 [==============================] - 10s 5s/step - loss: 0.0559 - accuracy: 1.0000 - val_loss: 2.4344 - val_accuracy: 0.6500
# Epoch 71/100
# 2/2 [==============================] - 10s 5s/step - loss: 0.0528 - accuracy: 1.0000 - val_loss: 2.5234 - val_accuracy: 0.6000
# Epoch 72/100
# 2/2 [==============================] - 10s 5s/step - loss: 0.0556 - accuracy: 1.0000 - val_loss: 2.2304 - val_accuracy: 0.6500
# Epoch 73/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.0534 - accuracy: 1.0000 - val_loss: 2.5317 - val_accuracy: 0.6000
# Epoch 74/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.0530 - accuracy: 1.0000 - val_loss: 2.5783 - val_accuracy: 0.6500
# Epoch 75/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0585 - accuracy: 0.9969 - val_loss: 3.0067 - val_accuracy: 0.6000
# Epoch 76/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0506 - accuracy: 1.0000 - val_loss: 2.6932 - val_accuracy: 0.6000
# Epoch 77/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0508 - accuracy: 1.0000 - val_loss: 2.7664 - val_accuracy: 0.6000
# Epoch 78/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0513 - accuracy: 1.0000 - val_loss: 2.3661 - val_accuracy: 0.6500
# Epoch 79/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0549 - accuracy: 0.9969 - val_loss: 2.4027 - val_accuracy: 0.6500
# Epoch 80/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0506 - accuracy: 1.0000 - val_loss: 2.6858 - val_accuracy: 0.6500
# Epoch 81/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0494 - accuracy: 1.0000 - val_loss: 2.7872 - val_accuracy: 0.6500
# Epoch 82/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0639 - accuracy: 0.9906 - val_loss: 3.5634 - val_accuracy: 0.7500
# Epoch 83/100
# 2/2 [==============================] - 8s 4s/step - loss: 1.8088 - accuracy: 0.7531 - val_loss: 0.9285 - val_accuracy: 0.5000
# Epoch 84/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.7071 - accuracy: 0.6594 - val_loss: 1.3540 - val_accuracy: 0.4000
# Epoch 85/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.5914 - accuracy: 0.7688 - val_loss: 1.6991 - val_accuracy: 0.4500
# Epoch 86/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.3944 - accuracy: 0.8656 - val_loss: 1.6897 - val_accuracy: 0.4500
# Epoch 87/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.2871 - accuracy: 0.9094 - val_loss: 2.7414 - val_accuracy: 0.4500
# Epoch 88/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.3661 - accuracy: 0.8719 - val_loss: 1.6020 - val_accuracy: 0.5500
# Epoch 89/100
# 2/2 [==============================] - 10s 5s/step - loss: 0.2086 - accuracy: 0.9625 - val_loss: 1.8081 - val_accuracy: 0.5500
# Epoch 90/100
# 2/2 [==============================] - 10s 5s/step - loss: 0.1355 - accuracy: 0.9812 - val_loss: 2.1872 - val_accuracy: 0.5500
# Epoch 91/100
# 2/2 [==============================] - 10s 5s/step - loss: 0.1143 - accuracy: 0.9844 - val_loss: 1.8845 - val_accuracy: 0.5500
# Epoch 92/100
# 2/2 [==============================] - 10s 5s/step - loss: 0.1050 - accuracy: 0.9906 - val_loss: 1.7272 - val_accuracy: 0.5500
# Epoch 93/100
# 2/2 [==============================] - 10s 4s/step - loss: 0.2297 - accuracy: 0.9281 - val_loss: 1.4542 - val_accuracy: 0.6000
# Epoch 94/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.2509 - accuracy: 0.9250 - val_loss: 1.8779 - val_accuracy: 0.6000
# Epoch 95/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.1264 - accuracy: 0.9812 - val_loss: 1.4833 - val_accuracy: 0.6000
# Epoch 96/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.1003 - accuracy: 0.9969 - val_loss: 1.7017 - val_accuracy: 0.6000
# Epoch 97/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.0957 - accuracy: 0.9875 - val_loss: 1.8487 - val_accuracy: 0.6000
# Epoch 98/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0895 - accuracy: 0.9937 - val_loss: 1.7512 - val_accuracy: 0.6000
# Epoch 99/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0780 - accuracy: 0.9969 - val_loss: 1.9458 - val_accuracy: 0.6000
# Epoch 100/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0990 - accuracy: 0.9844 - val_loss: 2.2593 - val_accuracy: 0.6500
#
#  Time cost:
#  888.2793047428131
