# %%
import tensorflow as tf
from tensorflow.keras.layers import Rescaling, Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers, callbacks
import time, json, os, shutil, argparse
import warnings
warnings.simplefilter("ignore")

# %%
epochs = 100
batch_size = 160
labels = ["0", "1"]
dir_models = "./Models/HC/G"
dir_training = "./Data/HC/G/"
dir_validation = "./Data/HC/O/Validation"
img_width, img_height, img_depth = 320, 240, 3
path_model = os.path.join(dir_models, 'resnet.h5')
path_history = os.path.join(dir_models, 'resnet.csv')

# %%
resnet_50 = tf.keras.applications.resnet50.ResNet50(include_top=False, weights='imagenet')
resnet_50.trainable=False

inputs = tf.keras.Input(shape=(img_width, img_height, img_depth))
x = resnet_50(inputs)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dense(64)(x)
x = tf.keras.layers.Activation('relu')(x)
x = tf.keras.layers.Dense(1)(x)
outputs = tf.keras.layers.Activation('sigmoid')(x)
model = tf.keras.Model(inputs=inputs, outputs=outputs, name="ResNet50_TL")
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Nadam(learning_rate=1e-4, epsilon=1e-08),
              metrics=['accuracy'])
#model.summary()

# %%
train_datagen = ImageDataGenerator(preprocessing_function=tf.keras.applications.resnet50.preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=tf.keras.applications.resnet50.preprocess_input)

train_generator = train_datagen.flow_from_directory(
    dir_training,
    target_size=(img_width, img_height),
    color_mode="rgb",
    batch_size=batch_size,
    class_mode='binary',
    shuffle=True,
    seed=42)

validation_generator = test_datagen.flow_from_directory(
    dir_validation,
    target_size=(img_width, img_height),
    color_mode="rgb",
    batch_size=batch_size,
    class_mode='binary',
    shuffle=True,
    seed=42)
# Out:
# Found 512 images belonging to 2 classes.
# Found 20 images belonging to 2 classes.

# %%
callback_log = callbacks.CSVLogger(path_history, append=True)
callback_model_save = callbacks.ModelCheckpoint(filepath=path_model, save_weights_only=False, monitor='val_accuracy', mode='max', save_best_only=True)

# %%
time_in = time.time()

hist = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator,
    callbacks=[callback_log, callback_model_save])

time_out = time.time()
print('\n', 'Time cost:', '\n', time_out-time_in)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 71s 16s/step - loss: 3.6042 - accuracy: 0.4961 - val_loss: 0.8908 - val_accuracy: 0.2000
# Epoch 2/100
# 4/4 [==============================] - 68s 16s/step - loss: 0.5405 - accuracy: 0.7227 - val_loss: 0.9323 - val_accuracy: 0.3500
# Epoch 3/100
# 4/4 [==============================] - 62s 19s/step - loss: 0.8490 - accuracy: 0.6016 - val_loss: 1.1884 - val_accuracy: 0.5000
# Epoch 4/100
# 4/4 [==============================] - 62s 15s/step - loss: 0.6169 - accuracy: 0.7949 - val_loss: 0.9677 - val_accuracy: 0.4500
# Epoch 5/100
# 4/4 [==============================] - 79s 19s/step - loss: 0.3744 - accuracy: 0.8242 - val_loss: 0.9694 - val_accuracy: 0.2000
# Epoch 6/100
# 4/4 [==============================] - 71s 16s/step - loss: 0.2163 - accuracy: 0.9648 - val_loss: 1.2724 - val_accuracy: 0.4500
# Epoch 7/100
# 4/4 [==============================] - 72s 18s/step - loss: 0.5470 - accuracy: 0.7090 - val_loss: 1.0809 - val_accuracy: 0.2000
# Epoch 8/100
# 4/4 [==============================] - 69s 15s/step - loss: 0.1474 - accuracy: 0.9805 - val_loss: 1.1016 - val_accuracy: 0.2500
# Epoch 9/100
# 4/4 [==============================] - 62s 14s/step - loss: 0.1308 - accuracy: 0.9824 - val_loss: 1.1313 - val_accuracy: 0.3500
# Epoch 10/100
# 4/4 [==============================] - 73s 18s/step - loss: 0.0894 - accuracy: 1.0000 - val_loss: 1.1435 - val_accuracy: 0.3000
# Epoch 11/100
# 4/4 [==============================] - 64s 14s/step - loss: 0.0749 - accuracy: 1.0000 - val_loss: 1.1537 - val_accuracy: 0.3000
# Epoch 12/100
# 4/4 [==============================] - 66s 16s/step - loss: 0.0631 - accuracy: 1.0000 - val_loss: 1.1380 - val_accuracy: 0.3500
# Epoch 13/100
# 4/4 [==============================] - 72s 16s/step - loss: 0.0556 - accuracy: 1.0000 - val_loss: 1.1426 - val_accuracy: 0.3500
# Epoch 14/100
# 4/4 [==============================] - 62s 14s/step - loss: 0.0526 - accuracy: 1.0000 - val_loss: 1.1337 - val_accuracy: 0.4000
# Epoch 15/100
# 4/4 [==============================] - 75s 23s/step - loss: 0.0444 - accuracy: 1.0000 - val_loss: 1.1378 - val_accuracy: 0.4000
# Epoch 16/100
# 4/4 [==============================] - 72s 17s/step - loss: 0.0453 - accuracy: 1.0000 - val_loss: 1.1307 - val_accuracy: 0.4000
# Epoch 17/100
# 4/4 [==============================] - 77s 19s/step - loss: 0.0392 - accuracy: 1.0000 - val_loss: 1.1208 - val_accuracy: 0.3500
# Epoch 18/100
# 4/4 [==============================] - 72s 16s/step - loss: 0.0359 - accuracy: 1.0000 - val_loss: 1.1549 - val_accuracy: 0.4500
# Epoch 19/100
# 4/4 [==============================] - 69s 16s/step - loss: 0.0339 - accuracy: 1.0000 - val_loss: 1.1526 - val_accuracy: 0.4500
# Epoch 20/100
# 4/4 [==============================] - 85s 19s/step - loss: 0.0314 - accuracy: 1.0000 - val_loss: 1.1598 - val_accuracy: 0.4500
# Epoch 21/100
# 4/4 [==============================] - 67s 15s/step - loss: 0.0276 - accuracy: 1.0000 - val_loss: 1.1965 - val_accuracy: 0.4500
# Epoch 22/100
# 4/4 [==============================] - 71s 17s/step - loss: 0.0267 - accuracy: 1.0000 - val_loss: 1.1704 - val_accuracy: 0.5500
# Epoch 23/100
# 4/4 [==============================] - 63s 14s/step - loss: 0.0264 - accuracy: 1.0000 - val_loss: 1.1653 - val_accuracy: 0.5000
# Epoch 24/100
# 4/4 [==============================] - 60s 14s/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 1.2299 - val_accuracy: 0.4500
# Epoch 25/100
# 4/4 [==============================] - 67s 21s/step - loss: 0.0230 - accuracy: 1.0000 - val_loss: 1.1818 - val_accuracy: 0.5500
# Epoch 26/100
# 4/4 [==============================] - 68s 16s/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 1.2033 - val_accuracy: 0.5000
# Epoch 27/100
# 4/4 [==============================] - 62s 14s/step - loss: 0.0190 - accuracy: 1.0000 - val_loss: 1.2230 - val_accuracy: 0.4500
# Epoch 28/100
# 4/4 [==============================] - 62s 15s/step - loss: 0.0195 - accuracy: 1.0000 - val_loss: 1.2369 - val_accuracy: 0.4500
# Epoch 29/100
# 4/4 [==============================] - 69s 15s/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 1.2657 - val_accuracy: 0.4500
# Epoch 30/100
# 4/4 [==============================] - 60s 14s/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 1.2509 - val_accuracy: 0.3500
# Epoch 31/100
# 4/4 [==============================] - 60s 14s/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 1.2871 - val_accuracy: 0.3500
# Epoch 32/100
# 4/4 [==============================] - 70s 17s/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 1.3042 - val_accuracy: 0.4000
# Epoch 33/100
# 4/4 [==============================] - 61s 19s/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 1.2948 - val_accuracy: 0.3000
# Epoch 34/100
# 4/4 [==============================] - 59s 14s/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 1.2937 - val_accuracy: 0.2500
# Epoch 35/100
# 4/4 [==============================] - 65s 16s/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 1.3133 - val_accuracy: 0.4000
# Epoch 36/100
# 4/4 [==============================] - 66s 20s/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 1.3067 - val_accuracy: 0.3500
# Epoch 37/100
# 4/4 [==============================] - 59s 14s/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 1.3065 - val_accuracy: 0.3000
# Epoch 38/100
# 4/4 [==============================] - 60s 14s/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 1.3159 - val_accuracy: 0.4000
# Epoch 39/100
# 4/4 [==============================] - 64s 15s/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 1.3141 - val_accuracy: 0.3000
# Epoch 40/100
# 4/4 [==============================] - 69s 15s/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 1.3107 - val_accuracy: 0.3000
# Epoch 41/100
# 4/4 [==============================] - 59s 14s/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 1.3116 - val_accuracy: 0.3000
# Epoch 42/100
# 4/4 [==============================] - 59s 18s/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 1.3135 - val_accuracy: 0.3000
# Epoch 43/100
# 4/4 [==============================] - 64s 15s/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 1.3172 - val_accuracy: 0.3000
# Epoch 44/100
# 4/4 [==============================] - 68s 15s/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 1.3042 - val_accuracy: 0.3000
# Epoch 45/100
# 4/4 [==============================] - 59s 14s/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 1.3046 - val_accuracy: 0.3000
# Epoch 46/100
# 4/4 [==============================] - 59s 14s/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 1.2924 - val_accuracy: 0.3500
# Epoch 47/100
# 4/4 [==============================] - 61s 14s/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 1.3128 - val_accuracy: 0.3000
# Epoch 48/100
# 4/4 [==============================] - 68s 15s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 1.3463 - val_accuracy: 0.4000
# Epoch 49/100
# 4/4 [==============================] - 59s 14s/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 1.2886 - val_accuracy: 0.3500
# Epoch 50/100
# 4/4 [==============================] - 59s 14s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 1.2990 - val_accuracy: 0.3500
# Epoch 51/100
# 4/4 [==============================] - 63s 15s/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 1.3056 - val_accuracy: 0.3000
# Epoch 52/100
# 4/4 [==============================] - 66s 20s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 1.3177 - val_accuracy: 0.4000
# Epoch 53/100
# 4/4 [==============================] - 59s 14s/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 1.3148 - val_accuracy: 0.3500
# Epoch 54/100
# 4/4 [==============================] - 60s 19s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 1.3191 - val_accuracy: 0.3500
# Epoch 55/100
# 4/4 [==============================] - 71s 17s/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.3218 - val_accuracy: 0.3500
# Epoch 56/100
# 4/4 [==============================] - 64s 20s/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.3238 - val_accuracy: 0.3500
# Epoch 57/100
# 4/4 [==============================] - 59s 14s/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 1.3235 - val_accuracy: 0.3500
# Epoch 58/100
# 4/4 [==============================] - 60s 14s/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 1.3253 - val_accuracy: 0.3500
# Epoch 59/100
# 4/4 [==============================] - 63s 15s/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.3275 - val_accuracy: 0.3500
# Epoch 60/100
# 4/4 [==============================] - 68s 15s/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.3291 - val_accuracy: 0.3500
# Epoch 61/100
# 4/4 [==============================] - 59s 14s/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.3326 - val_accuracy: 0.3500
# Epoch 62/100
# 4/4 [==============================] - 65s 20s/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.3300 - val_accuracy: 0.3500
# Epoch 63/100
# 4/4 [==============================] - 63s 15s/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.3287 - val_accuracy: 0.3500
# Epoch 64/100
# 4/4 [==============================] - 77s 18s/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.3322 - val_accuracy: 0.3500
# Epoch 65/100
# 4/4 [==============================] - 64s 15s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.3984 - val_accuracy: 0.4000
# Epoch 66/100
# 4/4 [==============================] - 63s 15s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.4138 - val_accuracy: 0.4000
# Epoch 67/100
# 4/4 [==============================] - 62s 14s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.4824 - val_accuracy: 0.4000
# Epoch 68/100
# 4/4 [==============================] - 62s 14s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.4814 - val_accuracy: 0.4000
# Epoch 69/100
# 4/4 [==============================] - 61s 14s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.4728 - val_accuracy: 0.4000
# Epoch 70/100
# 4/4 [==============================] - 61s 14s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.4165 - val_accuracy: 0.4000
# Epoch 71/100
# 4/4 [==============================] - 62s 14s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.4250 - val_accuracy: 0.4000
# Epoch 72/100
# 4/4 [==============================] - 82s 20s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.4543 - val_accuracy: 0.4500
# Epoch 73/100
# 4/4 [==============================] - 67s 15s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.4432 - val_accuracy: 0.4500
# Epoch 74/100
# 4/4 [==============================] - 73s 17s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.4608 - val_accuracy: 0.4000
# Epoch 75/100
# 4/4 [==============================] - 69s 15s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.5007 - val_accuracy: 0.4500
# Epoch 76/100
# 4/4 [==============================] - 71s 17s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.4622 - val_accuracy: 0.4500
# Epoch 77/100
# 4/4 [==============================] - 72s 16s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.5259 - val_accuracy: 0.4000
# Epoch 78/100
# 4/4 [==============================] - 61s 14s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.5203 - val_accuracy: 0.4500
# Epoch 79/100
# 4/4 [==============================] - 76s 18s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.5245 - val_accuracy: 0.4500
# Epoch 80/100
# 4/4 [==============================] - 66s 15s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.5286 - val_accuracy: 0.4500
# Epoch 81/100
# 4/4 [==============================] - 76s 18s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.5647 - val_accuracy: 0.4000
# Epoch 82/100
# 4/4 [==============================] - 66s 15s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.5352 - val_accuracy: 0.4500
# Epoch 83/100
# 4/4 [==============================] - 64s 15s/step - loss: 9.9688e-04 - accuracy: 1.0000 - val_loss: 1.5827 - val_accuracy: 0.4000
# Epoch 84/100
# 4/4 [==============================] - 74s 17s/step - loss: 9.1680e-04 - accuracy: 1.0000 - val_loss: 1.5668 - val_accuracy: 0.4000
# Epoch 85/100
# 4/4 [==============================] - 65s 20s/step - loss: 8.3867e-04 - accuracy: 1.0000 - val_loss: 1.5557 - val_accuracy: 0.4500
# Epoch 86/100
# 4/4 [==============================] - 73s 23s/step - loss: 8.8354e-04 - accuracy: 1.0000 - val_loss: 1.5676 - val_accuracy: 0.4500
# Epoch 87/100
# 4/4 [==============================] - 66s 14s/step - loss: 8.5431e-04 - accuracy: 1.0000 - val_loss: 1.5775 - val_accuracy: 0.4000
# Epoch 88/100
# 4/4 [==============================] - 63s 14s/step - loss: 7.7908e-04 - accuracy: 1.0000 - val_loss: 1.5731 - val_accuracy: 0.4500
# Epoch 89/100
# 4/4 [==============================] - 77s 24s/step - loss: 7.0689e-04 - accuracy: 1.0000 - val_loss: 1.5725 - val_accuracy: 0.4500
# Epoch 90/100
# 4/4 [==============================] - 64s 14s/step - loss: 7.1991e-04 - accuracy: 1.0000 - val_loss: 1.5881 - val_accuracy: 0.4500
# Epoch 91/100
# 4/4 [==============================] - 66s 21s/step - loss: 6.4967e-04 - accuracy: 1.0000 - val_loss: 1.5711 - val_accuracy: 0.4500
# Epoch 92/100
# 4/4 [==============================] - 72s 22s/step - loss: 6.5115e-04 - accuracy: 1.0000 - val_loss: 1.5886 - val_accuracy: 0.4500
# Epoch 93/100
# 4/4 [==============================] - 61s 14s/step - loss: 6.1816e-04 - accuracy: 1.0000 - val_loss: 1.5901 - val_accuracy: 0.4500
# Epoch 94/100
# 4/4 [==============================] - 76s 18s/step - loss: 5.9902e-04 - accuracy: 1.0000 - val_loss: 1.5927 - val_accuracy: 0.4500
# Epoch 95/100
# 4/4 [==============================] - 62s 19s/step - loss: 6.0332e-04 - accuracy: 1.0000 - val_loss: 1.5870 - val_accuracy: 0.4500
# Epoch 96/100
# 4/4 [==============================] - 69s 22s/step - loss: 5.4626e-04 - accuracy: 1.0000 - val_loss: 1.6019 - val_accuracy: 0.4500
# Epoch 97/100
# 4/4 [==============================] - 70s 15s/step - loss: 5.2856e-04 - accuracy: 1.0000 - val_loss: 1.5975 - val_accuracy: 0.4500
# Epoch 98/100
# 4/4 [==============================] - 63s 15s/step - loss: 5.1225e-04 - accuracy: 1.0000 - val_loss: 1.6139 - val_accuracy: 0.4500
# Epoch 99/100
# 4/4 [==============================] - 75s 24s/step - loss: 5.3190e-04 - accuracy: 1.0000 - val_loss: 1.6003 - val_accuracy: 0.4500
# Epoch 100/100
# 4/4 [==============================] - 63s 14s/step - loss: 4.7358e-04 - accuracy: 1.0000 - val_loss: 1.6089 - val_accuracy: 0.4500
#
#  Time cost:
#  6638.771132946014
